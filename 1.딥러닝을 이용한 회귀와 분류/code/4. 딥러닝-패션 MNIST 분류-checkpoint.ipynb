# %% [markdown]
# # 딥러닝으로 패션 MNIST 분류하기

# %% [markdown]
# ### 텐서플로우와 케라스 라이브러리 import 및 버전 확인

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %% [markdown]
# ## 패션 MNIST 데이타셋
# - 패션 아이템 이미지
# - 28*28 픽셀 크기의 흑백이미지 70,000개
#     - 케라스에서 60,000개의 학습 데이타셋, 10,000개의 테스트 데이타셋으로 제공
# - 10개의 클래스
#     - T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
# - 픽셀 강도
#     - 0 ~ 255의 정수로 표현

# %% [markdown]
# <img src="./img/fashon-mnist.png" width=600 align="left">

# %% [markdown]
# ### 1. Fashion-MNIST 데이터셋 로드하기
# ### 1) 데이타 로드

# %%
from tensorflow.keras.datasets.fashion_mnist import load_data

# Fashion-MNIST 데이터 로드
(x_train, y_train), (x_test, y_test) = load_data()

# 데이타 형태 확인
print(x_train.shape, y_train.shape)
print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)
# (60000, 28, 28) (60000,)

# %% [markdown]
# ### 2) 데이터 이미지로 그려보기

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(777)

# Fashion-MNIST의 레이블에 해당하는 품목입니다.
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

sample_size = 9
# 0 ~ 59999의 범위에서 무작위로 3개의 정수 추출
random_idx = np.random.randint(60000, size=sample_size) 

plt.figure(figsize = (5, 5))
for i, idx in enumerate(random_idx):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[idx], cmap = 'gray') 
    plt.xlabel(class_names[y_train[idx]]) 
    
plt.show()

# %% [markdown]
# ### 2. 피쳐 전처리/레이블 범주형 데이타로 변경하기

# %%
# 피쳐 값의 정규화 : 범위를 0 ~ 1로 만든다.
x_train = x_train / 255
x_test = x_test / 255

# 레이블 범주화 
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### 3. 검증 데이타셋 만들기

# %%
from sklearn.model_selection import train_test_split

# 학습/검증 데이터셋을 0.7/0.3의 비율로 분리합니다.
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                  test_size = 0.3, 
                                                  random_state = 777,
                                                  stratify = y_train)
# 데이타 형태 확인
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (29400, 28, 28) (29400, 10)
# (12600, 28, 28) (12600, 10)
# (10000, 28, 28) (10000, 10)

# %% [markdown]
# ### 4. 딥러닝 모델 구성하기

# %% [markdown]
# ### 4.1 첫 번째 모델

# %% [markdown]
# #### 1) 첫번째 모델 구성하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

first_model = Sequential()

first_model.add(Flatten(input_shape = (28, 28)))   # 1) 입력층 : (28, 28) -> 28 * 28 = 784
first_model.add(Dense(64, activation = 'relu'))    # 2) 은닉층1 : 64개의 출력을 가지는 Dense 층
first_model.add(Dense(32, activation = 'relu'))    # 3) 은닉층2 : 32개의 출력을 가지는 Dense 층
first_model.add(Dense(10, activation = 'softmax')) # 4) 출력층 : 10개의 출력을 가지는 Dense 층

# %%
# 모델 요약
first_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Param #
#     - 1) 입력층(flatten)
#     - 2) 은닉층1(dense) = 784(입력) X 64(은닉층1 노드) + 64(biases) = 50,240개
#     - 3) 은닉층2(dense_1) = 64(은닉층1 노드) X 32(은닉층2 노드) + 32(biases) = 2,080개
#     - 4) 출력층(dense_2) = 32(은닉츠2 노드) X 10(출력개수) + 10(biases) = 330개

# %% [markdown]
# ####  2) 컴파일 설정

# %%
first_model.compile(optimizer='adam',            # 최적화 함수 : adam
              loss = 'categorical_crossentropy', # 손실 함수 : categorical_crossentropy
              metrics=['acc'])                   # 모니터링 할 평가지표 : acc

# %% [markdown]
# #### 3) 모델 실행

# %%
first_history = first_model.fit(x_train, y_train, 
                    epochs = 30, 
                    batch_size = 128, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.7545 - acc: 0.7453 - val_loss: 0.5147 - val_acc: 0.8283
# Epoch 2/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.4711 - acc: 0.8352 - val_loss: 0.4435 - val_acc: 0.8466
# Epoch 3/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.4200 - acc: 0.8524 - val_loss: 0.4238 - val_acc: 0.8525
# Epoch 4/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3924 - acc: 0.8597 - val_loss: 0.4050 - val_acc: 0.8561
# Epoch 5/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3718 - acc: 0.8664 - val_loss: 0.3960 - val_acc: 0.8598
# Epoch 6/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3558 - acc: 0.8725 - val_loss: 0.3893 - val_acc: 0.8609
# Epoch 7/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3449 - acc: 0.8754 - val_loss: 0.4045 - val_acc: 0.8579
# Epoch 8/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3289 - acc: 0.8822 - val_loss: 0.3686 - val_acc: 0.8717
# Epoch 9/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3212 - acc: 0.8845 - val_loss: 0.3681 - val_acc: 0.8696
# Epoch 10/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3123 - acc: 0.8853 - val_loss: 0.3962 - val_acc: 0.8603
# Epoch 11/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3051 - acc: 0.8903 - val_loss: 0.3567 - val_acc: 0.8729
# Epoch 12/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2976 - acc: 0.8932 - val_loss: 0.3639 - val_acc: 0.8726
# Epoch 13/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2854 - acc: 0.8950 - val_loss: 0.3491 - val_acc: 0.8760
# Epoch 14/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2783 - acc: 0.8982 - val_loss: 0.3624 - val_acc: 0.8729
# Epoch 15/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2756 - acc: 0.8988 - val_loss: 0.3732 - val_acc: 0.8677
# Epoch 16/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2623 - acc: 0.9038 - val_loss: 0.3585 - val_acc: 0.8745
# Epoch 17/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2653 - acc: 0.9020 - val_loss: 0.3557 - val_acc: 0.8744
# Epoch 18/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2555 - acc: 0.9061 - val_loss: 0.3505 - val_acc: 0.8797
# Epoch 19/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2500 - acc: 0.9080 - val_loss: 0.3624 - val_acc: 0.8752
# Epoch 20/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2459 - acc: 0.9095 - val_loss: 0.3516 - val_acc: 0.8789
# Epoch 21/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2399 - acc: 0.9114 - val_loss: 0.3570 - val_acc: 0.8766
# Epoch 22/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2346 - acc: 0.9136 - val_loss: 0.3861 - val_acc: 0.8649
# Epoch 23/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2318 - acc: 0.9151 - val_loss: 0.3555 - val_acc: 0.8806
# Epoch 24/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2215 - acc: 0.9190 - val_loss: 0.3694 - val_acc: 0.8752
# Epoch 25/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2184 - acc: 0.9196 - val_loss: 0.3494 - val_acc: 0.8806
# Epoch 26/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2170 - acc: 0.9230 - val_loss: 0.3687 - val_acc: 0.8768
# Epoch 27/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2166 - acc: 0.9208 - val_loss: 0.3820 - val_acc: 0.8690
# Epoch 28/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2137 - acc: 0.9215 - val_loss: 0.3850 - val_acc: 0.8721
# Epoch 29/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2062 - acc: 0.9255 - val_loss: 0.3808 - val_acc: 0.8737
# Epoch 30/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2012 - acc: 0.9259 - val_loss: 0.3640 - val_acc: 0.8794

# %% [markdown]
# #### 4) 모델 평가

# %%
# 첫번째 모델 평가하기
first_model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3918 - acc: 0.8685
# [0.3917587995529175, 0.8684999942779541]

# %% [markdown]
# #### 5) Early_stopping  콜백 사용하여 모델 학습

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
first_history2 = first_model.fit(x_train, y_train, 
                    epochs = 30, 
                    batch_size = 128, 
                    validation_data = (x_val, y_val),
                    callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 219/230 [===========================>..] - ETA: 0s - loss: 0.1311 - acc: 0.9524
# Epoch 00001: val_loss improved from inf to 0.43972, saving model to ./model/01-0.4397.hdf5
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1321 - acc: 0.9520 - val_loss: 0.4397 - val_acc: 0.8741
# Epoch 2/30
# 219/230 [===========================>..] - ETA: 0s - loss: 0.1360 - acc: 0.9506
# Epoch 00002: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1353 - acc: 0.9508 - val_loss: 0.4490 - val_acc: 0.8748
# Epoch 3/30
# 205/230 [=========================>....] - ETA: 0s - loss: 0.1246 - acc: 0.9551
# Epoch 00003: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1240 - acc: 0.9553 - val_loss: 0.4801 - val_acc: 0.8771
# Epoch 4/30
# 212/230 [==========================>...] - ETA: 0s - loss: 0.1234 - acc: 0.9552- ETA: 0s - loss: 0.1233 - acc: 0.955
# Epoch 00004: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1240 - acc: 0.9554 - val_loss: 0.4774 - val_acc: 0.8744
# Epoch 5/30
# 218/230 [===========================>..] - ETA: 0s - loss: 0.1269 - acc: 0.9543
# Epoch 00005: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1269 - acc: 0.9542 - val_loss: 0.4535 - val_acc: 0.8755
# Epoch 6/30
# 224/230 [============================>.] - ETA: 0s - loss: 0.1270 - acc: 0.9544
# Epoch 00006: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1266 - acc: 0.9543 - val_loss: 0.4847 - val_acc: 0.8720
# Epoch 7/30
# 225/230 [============================>.] - ETA: 0s - loss: 0.1249 - acc: 0.9548
# Epoch 00007: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1255 - acc: 0.9545 - val_loss: 0.4498 - val_acc: 0.8749
# Epoch 8/30
# 212/230 [==========================>...] - ETA: 0s - loss: 0.1190 - acc: 0.9571
# Epoch 00008: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1216 - acc: 0.9560 - val_loss: 0.4911 - val_acc: 0.8737
# Epoch 9/30
# 215/230 [===========================>..] - ETA: 0s - loss: 0.1213 - acc: 0.9561
# Epoch 00009: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1201 - acc: 0.9565 - val_loss: 0.4898 - val_acc: 0.8743
# Epoch 10/30
# 227/230 [============================>.] - ETA: 0s - loss: 0.1153 - acc: 0.9585
# Epoch 00010: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1152 - acc: 0.9585 - val_loss: 0.4806 - val_acc: 0.8779
# Epoch 11/30
# 223/230 [============================>.] - ETA: 0s - loss: 0.1145 - acc: 0.9587
# Epoch 00011: val_loss did not improve from 0.43972
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1147 - acc: 0.9587 - val_loss: 0.5146 - val_acc: 0.8711

# %%
# Early_stopping 콜백을 이용한 모델 평가하기
first_model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5650 - acc: 0.8597
# [0.5650193095207214, 0.8597000241279602]

# %% [markdown]
# ### 4.2 두 번째 모델

# %% [markdown]
# #### 1) 모델 구성하기

# %%
second_model = Sequential()

second_model.add(Flatten(input_shape = (28, 28))) # 1) 입력층 : (28, 28) -> 28 * 28 = 784
second_model.add(Dense(128, activation = 'relu')) # 2) 은닉층1 : 128개의 출력을 가지는 Dense 층
second_model.add(Dense(64, activation = 'relu'))  # 3) 은닉층2: 64개의 출력을 가지는 Dense 층
second_model.add(Dense(32, activation = 'relu'))  # 4) 은닉층3 : 32개의 출력을 가지는 Dense 층
second_model.add(Dense(10, activation = 'softmax')) # 5) 출력층 : 10개의 출력을 가지는 Dense 층

# %%
# 모델 요약
second_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                330
# =================================================================
# Total params: 111,146
# Trainable params: 111,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 4) 컴파일 설정

# %%
second_model.compile(optimizer='adam',           # 최적화 함수: adam
              loss = 'categorical_crossentropy', # 손실 함수: categorical_crossentropy
              metrics=['acc'])                   # 모니터링 할 평가지표: acc(정확도)

# %% [markdown]
# #### 5) 모델 학습

# %%
second_history = second_model.fit(x_train, y_train, 
                    epochs = 30, 
                    batch_size = 128, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.7002 - acc: 0.7514 - val_loss: 0.5072 - val_acc: 0.8263
# Epoch 2/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.4467 - acc: 0.8415 - val_loss: 0.4413 - val_acc: 0.8403
# Epoch 3/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.4014 - acc: 0.8549 - val_loss: 0.4175 - val_acc: 0.8505
# Epoch 4/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3677 - acc: 0.8687 - val_loss: 0.3906 - val_acc: 0.8604
# Epoch 5/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3442 - acc: 0.8763 - val_loss: 0.4019 - val_acc: 0.8556
# Epoch 6/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3297 - acc: 0.8787 - val_loss: 0.3822 - val_acc: 0.8624
# Epoch 7/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.3070 - acc: 0.8865 - val_loss: 0.3516 - val_acc: 0.8763
# Epoch 8/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.3011 - acc: 0.8885 - val_loss: 0.3696 - val_acc: 0.8694
# Epoch 9/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2872 - acc: 0.8930 - val_loss: 0.3533 - val_acc: 0.8762
# Epoch 10/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2751 - acc: 0.8980 - val_loss: 0.3516 - val_acc: 0.8765
# Epoch 11/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2638 - acc: 0.9016 - val_loss: 0.3467 - val_acc: 0.8738
# Epoch 12/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2547 - acc: 0.9057 - val_loss: 0.3494 - val_acc: 0.8782
# Epoch 13/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2534 - acc: 0.9061 - val_loss: 0.3473 - val_acc: 0.8781
# Epoch 14/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2439 - acc: 0.9077 - val_loss: 0.3327 - val_acc: 0.8813
# Epoch 15/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2330 - acc: 0.9143 - val_loss: 0.3662 - val_acc: 0.8767
# Epoch 16/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.2282 - acc: 0.9152 - val_loss: 0.3494 - val_acc: 0.8808
# Epoch 17/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2206 - acc: 0.9191 - val_loss: 0.3527 - val_acc: 0.8802
# Epoch 18/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2123 - acc: 0.9211 - val_loss: 0.3483 - val_acc: 0.8807
# Epoch 19/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2109 - acc: 0.9188 - val_loss: 0.3540 - val_acc: 0.8835
# Epoch 20/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.2054 - acc: 0.9243 - val_loss: 0.3493 - val_acc: 0.8823
# Epoch 21/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1976 - acc: 0.9265 - val_loss: 0.3726 - val_acc: 0.8706
# Epoch 22/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1921 - acc: 0.9277 - val_loss: 0.3595 - val_acc: 0.8783
# Epoch 23/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1859 - acc: 0.9309 - val_loss: 0.4280 - val_acc: 0.8675
# Epoch 24/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1833 - acc: 0.9315 - val_loss: 0.3562 - val_acc: 0.8844
# Epoch 25/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1764 - acc: 0.9336 - val_loss: 0.3846 - val_acc: 0.8723
# Epoch 26/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1691 - acc: 0.9347 - val_loss: 0.3866 - val_acc: 0.8861
# Epoch 27/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1707 - acc: 0.9360 - val_loss: 0.3700 - val_acc: 0.8852
# Epoch 28/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1600 - acc: 0.9385 - val_loss: 0.4048 - val_acc: 0.8748
# Epoch 29/30
# 230/230 [==============================] - 1s 3ms/step - loss: 0.1625 - acc: 0.9389 - val_loss: 0.4106 - val_acc: 0.8763
# Epoch 30/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.1523 - acc: 0.9428 - val_loss: 0.3986 - val_acc: 0.8833

# %% [markdown]
# #### 6) 모델 평가

# %%
# 두번째 모델 평가
second_model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4418 - acc: 0.8712
# [0.441803902387619, 0.8712000250816345]

# %% [markdown]
# #### 7) 두번째 모델을 이용한 예측

# %%
import numpy as np
np.set_printoptions(precision=7) # numpy 소수점 제한

results = second_model.predict(x_test)

print(results.shape)
print(f'각 클래스에 속할 확률 : \n{results[0]}')
print(f'예상 클래스 : {results[0].argmax()}')
# Out:
# (10000, 10)
# 각 클래스에 속할 확률 :
# [7.9148442e-08 2.5037633e-07 5.5095006e-07 1.1487352e-08 2.8174833e-08
#  2.2898093e-06 7.4589686e-09 3.6528535e-04 1.8098186e-08 9.9963140e-01]
# 예상 클래스 : 9

# %% [markdown]
# #### 8) 예측한 데이타 이미지로 확인하기

# %%
import matplotlib.pyplot as plt

arg_results = np.argmax(results, axis = -1) # 가장 큰 값의 인덱스를 가져옵니다.
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# 예측 결과를 이미지로 보여주기
plt.imshow(x_test[0].reshape(28, 28))
title = 'Predicted value of the first image : ' + str(arg_results[0]) + ', ' + class_names[arg_results[0]]
plt.title(title, fontsize = 12)
plt.show()

# %% [markdown]
# ### 5. 두 모델의 학습 과정 그려보기

# %%
import numpy as np
import matplotlib.pyplot as plt

def draw_loss_acc(history_1, history_2, epochs):
    his_dict_1 = history_1.history
    his_dict_2 = history_2.history
    keys = list(his_dict_1.keys())
    
    epochs = range(1, epochs)
    fig = plt.figure(figsize = (8,6))
    ax = fig.add_subplot(1, 1, 1)
    
    # axis 선과 ax의 축 레이블 제거
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')
    ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)
    
    for i in range(len(his_dict_1)):
        temp_ax = fig.add_subplot(2, 2, i + 1)
        temp = keys[i%2]
        val_temp = keys[(i + 2)%2 + 2]
        temp_history = his_dict_1 if i < 2 else his_dict_2
        temp_ax.plot(epochs, temp_history[temp][1:], color = 'blue', label = 'train_' + temp)
        temp_ax.plot(epochs, temp_history[val_temp][1:], color = 'orange', label = val_temp)
        if(i == 1 or i == 3):
            start, end = temp_ax.get_ylim()
            temp_ax.yaxis.set_ticks(np.arange(np.round(start, 2), end, 0.01))            
        temp_ax.legend()
    ax.set_ylabel('loss', size = 15)
    ax.set_xlabel('epochs', size = 15)
    plt.tight_layout()
    plt.show()
    
draw_loss_acc(first_history, second_history, 30)

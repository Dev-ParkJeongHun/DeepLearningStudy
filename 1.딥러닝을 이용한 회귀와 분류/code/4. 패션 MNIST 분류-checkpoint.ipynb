# %% [markdown]
# # 딥러닝으로 패션 MNIST 분류하기

# %%
# 경고 무시
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### 텐서플로우와 케라스 라이브러리 import 및 버전 확인

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %% [markdown]
# ## 패션 MNIST 데이타셋
# - 패션 아이템 이미지
# - 28*28 픽셀 크기의 흑백이미지 70,000개
#     - 케라스에서 60,000개의 학습 데이타셋, 10,000개의 테스트 데이타셋으로 제공
# - 10개의 클래스
#     - T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot
# - 픽셀 강도
#     - 0 ~ 255의 정수로 표현

# %% [markdown]
# <img src="./img/fashon-mnist.png" width=600 align="left">

# %% [markdown]
# ### 1. Fashion-MNIST 데이터셋 로드하기
# ### 1) 데이타 로드

# %%
from tensorflow.keras.datasets.fashion_mnist import load_data

# Fashion-MNIST 데이터 로드
(x_train, y_train), (x_test, y_test) = load_data()

# 데이타 형태 확인
print(x_train.shape, y_train.shape)
print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)
# (60000, 28, 28) (60000,)

# %% [markdown]
# ### 2) 데이터 이미지로 그려보기

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(777)

# Fashion-MNIST의 레이블에 해당하는 품목입니다.
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

sample_size = 9
# 0 ~ 59999의 범위에서 무작위로 3개의 정수 추출
random_idx = np.random.randint(60000, size=sample_size) 

plt.figure(figsize = (5, 5))
for i, idx in enumerate(random_idx):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[idx], cmap = 'gray') 
    plt.xlabel(class_names[y_train[idx]]) 
    
plt.show()

# %% [markdown]
# ### 2. 피쳐 전처리/레이블 범주형 데이타로 변경하기

# %%
# 피쳐 값의 정규화 : 범위를 0 ~ 1로 만든다.
x_train = x_train / 255
x_test = x_test / 255

# 레이블 범주화 
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### 3. 검증 데이타셋 만들기

# %%
from sklearn.model_selection import train_test_split

# 학습/검증 데이터셋을 0.7/0.3의 비율로 분리합니다.
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                  test_size = 0.3, 
                                                  random_state = 777,
                                                  stratify = y_train)
# 데이타 형태 확인
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (42000, 28, 28) (42000, 10)
# (18000, 28, 28) (18000, 10)
# (10000, 28, 28) (10000, 10)

# %% [markdown]
# ### 4. 딥러닝 모델 구성하기

# %% [markdown]
# ### 4.1 첫 번째 모델

# %% [markdown]
# ### 1) 첫번째 모델 구성하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

first_model = Sequential()

first_model.add(Flatten(input_shape = (28, 28)))   # 1) 입력층 : (28, 28) -> 28 * 28 = 784
first_model.add(Dense(64, activation = 'relu'))    # 2) 은닉층1 : 64개의 출력을 가지는 Dense 층
first_model.add(Dense(32, activation = 'relu'))    # 3) 은닉층2 : 32개의 출력을 가지는 Dense 층
first_model.add(Dense(10, activation = 'softmax')) # 4) 출력층 : 10개의 출력을 가지는 Dense 층

# %%
# 모델 요약
first_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# ...
# Total params: 52,650
# Trainable params: 52,650
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Param #
#     - 1) 입력층(flatten)
#     - 2) 은닉층1(dense) = 784(입력) X 64(은닉층1 노드) + 64(biases) = 50,240개
#     - 3) 은닉층2(dense_1) = 64(은닉층1 노드) X 32(은닉층2 노드) + 32(biases) = 2,080개
#     - 4) 출력층(dense_2) = 32(은닉츠2 노드) X 10(출력개수) + 10(biases) = 330개

# %% [markdown]
# ###  2) 컴파일 설정

# %%
first_model.compile(optimizer='adam',            # 최적화 함수 : adam
              loss = 'categorical_crossentropy', # 손실 함수 : categorical_crossentropy
              metrics=['acc'])                   # 모니터링 할 평가지표 : acc

# %% [markdown]
# ### 3) 모델 실행

# %%
first_history = first_model.fit(x_train, y_train, 
                    epochs = 30, 
                    batch_size = 128, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000024F49E61D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000024F49E61D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %% [markdown]
# ### 4) 모델 평가

# %%
# 첫번째 모델 평가하기
first_model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3943 - acc: 0.8722
# [0.3942582905292511, 0.8722000122070312]

# %% [markdown]
# ### 5) Early_stopping  콜백 사용하여 모델 학습

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os

# 딥러닝 모델을 저장할 디렉토리(폴더) 생성
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./data/model/Fashion_MNIST_MLP.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
first_history2 = first_model.fit(x_train, y_train, 
                    epochs = 30, 
                    batch_size = 128, 
                    validation_data = (x_val, y_val),
                    callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 309/329 [===========================>..] - ETA: 0s - loss: 0.1858 - acc: 0.9309
# Epoch 00001: val_loss improved from inf to 0.35837, saving model to ./model/01-0.3584.hdf5
# 329/329 [==============================] - 2s 6ms/step - loss: 0.1873 - acc: 0.9304 - val_loss: 0.3584 - val_acc: 0.8803
# Epoch 2/30
# 326/329 [============================>.] - ETA: 0s - loss: 0.1858 - acc: 0.9315
# Epoch 00002: val_loss did not improve from 0.35837
# 329/329 [==============================] - 2s 6ms/step - loss: 0.1858 - acc: 0.9315 - val_loss: 0.3709 - val_acc: 0.8810
# Epoch 3/30
# 323/329 [============================>.] - ETA: 0s - loss: 0.1817 - acc: 0.9313
# Epoch 00003: val_loss did not improve from 0.35837
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1824 - acc: 0.9310 - val_loss: 0.3685 - val_acc: 0.8822
# Epoch 4/30
# 320/329 [============================>.] - ETA: 0s - loss: 0.1806 - acc: 0.9335
# ...

# %%
# Early_stopping 콜백을 이용한 모델 평가하기
first_model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4185 - acc: 0.8750
# [0.4184766709804535, 0.875]

# %% [markdown]
# ### 4.2 두 번째 모델

# %% [markdown]
# ### 1) 모델 구성하기

# %%
second_model = Sequential()

second_model.add(Flatten(input_shape = (28, 28))) # 1) 입력층 : (28, 28) -> 28 * 28 = 784
second_model.add(Dense(128, activation = 'relu')) # 2) 은닉층1 : 128개의 출력을 가지는 Dense 층
second_model.add(Dense(64, activation = 'relu'))  # 3) 은닉층2: 64개의 출력을 가지는 Dense 층
second_model.add(Dense(32, activation = 'relu'))  # 4) 은닉층3 : 32개의 출력을 가지는 Dense 층
second_model.add(Dense(10, activation = 'softmax')) # 5) 출력층 : 10개의 출력을 가지는 Dense 층

# %%
# 모델 요약
second_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                330
# ...
# Total params: 111,146
# Trainable params: 111,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2) 컴파일 설정

# %%
second_model.compile(optimizer='adam',           # 최적화 함수: adam
              loss = 'categorical_crossentropy', # 손실 함수: categorical_crossentropy
              metrics=['acc'])                   # 모니터링 할 평가지표: acc(정확도)

# %% [markdown]
# ### 3) 모델 학습

# %%
second_history = second_model.fit(x_train, y_train, 
                    epochs = 30, 
                    batch_size = 128, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000024F4AF13438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000024F4AF13438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %% [markdown]
# ### 4) 모델 평가

# %%
# 두번째 모델 평가
second_model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4125 - acc: 0.8809
# [0.4125228524208069, 0.8809000253677368]

# %% [markdown]
# ### 5) 두번째 모델을 이용한 예측

# %%
import numpy as np
np.set_printoptions(precision=7) # numpy 소수점 제한

results = second_model.predict(x_test)

print(results.shape)
print(f'각 클래스에 속할 확률 : \n{results[0]}')
print(f'예상 클래스 : {results[0].argmax()}')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000024F4CFD7B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000024F4CFD7B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (10000, 10)
# 각 클래스에 속할 확률 :
# ...

# %% [markdown]
# ### 6) 예측한 데이타 이미지로 확인하기

# %%
import matplotlib.pyplot as plt

arg_results = np.argmax(results, axis = -1) # 가장 큰 값의 인덱스를 가져옵니다.
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# 예측 결과를 이미지로 보여주기
plt.imshow(x_test[0].reshape(28, 28))
title = 'Predicted value of the first image : ' + str(arg_results[0]) + ', ' + class_names[arg_results[0]]
plt.title(title, fontsize = 12)
plt.show()

# %% [markdown]
# ### 5. 두 모델의 학습 과정 그려보기

# %%
import numpy as np
import matplotlib.pyplot as plt

def draw_loss_acc(history_1, history_2, epochs):
    his_dict_1 = history_1.history
    his_dict_2 = history_2.history
    keys = list(his_dict_1.keys())
    
    epochs = range(1, epochs)
    fig = plt.figure(figsize = (8,6))
    ax = fig.add_subplot(1, 1, 1)
    
    # axis 선과 ax의 축 레이블 제거
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')
    ax.tick_params(labelcolor='w', top=False, bottom=False, left=False, right=False)
    
    for i in range(len(his_dict_1)):
        temp_ax = fig.add_subplot(2, 2, i + 1)
        temp = keys[i%2]
        val_temp = keys[(i + 2)%2 + 2]
        temp_history = his_dict_1 if i < 2 else his_dict_2
        temp_ax.plot(epochs, temp_history[temp][1:], color = 'blue', label = 'train_' + temp)
        temp_ax.plot(epochs, temp_history[val_temp][1:], color = 'orange', label = val_temp)
        if(i == 1 or i == 3):
            start, end = temp_ax.get_ylim()
            temp_ax.yaxis.set_ticks(np.arange(np.round(start, 2), end, 0.01))            
        temp_ax.legend()
    ax.set_ylabel('loss', size = 15)
    ax.set_xlabel('epochs', size = 15)
    plt.tight_layout()
    plt.show()
    
draw_loss_acc(first_history, second_history, 30)
